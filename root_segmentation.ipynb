# %%
import skimage
from skimage import io
from skimage.feature import canny
import matplotlib.pyplot as plt
import cv2
import scipy
from scipy import ndimage

# %%
img= io.imread("28\\1-2020-01-28_00-00_0003.png",as_gray=True)
plt.figure(figsize=(12, 4))
plt.subplot(131)
plt.title('Image')
plt.imshow(img)
canny_edge=canny(img, 0.2)
blur= ndimage.gaussian_filter(img, 0.5)
canny_b= canny(blur, 1)
plt.subplot(132)
plt.imshow(canny_edge)
plt.title('Edge detection using Canny')
plt.subplot(133)
plt.imshow(canny_b)
plt.title('Edge detection using Canny + Gaussian blur')
# Out:
# Text(0.5, 1.0, 'Edge detection using Canny + Gaussian blur')

# %%
canny_edge
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False,  True, ..., False, False, False],
#        [False, False,  True, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
img= io.imread("28\\1-2020-01-28_00-00_0003.png",as_gray=True).astype(float)


blurred_f = ndimage.gaussian_filter(img, 0.6)
filter_blurred_f = ndimage.gaussian_filter(blurred_f, 1)
alpha = 30
sharpened = blurred_f + alpha * (blurred_f - filter_blurred_f)
plt.figure(figsize=(12, 4))

plt.subplot(151)
plt.imshow(img, cmap=plt.cm.gray)
plt.title('img')
plt.axis('off')
plt.subplot(152)
plt.imshow(blurred_f, cmap=plt.cm.gray)
plt.title('b_f')
plt.axis('off')
plt.subplot(153)
plt.imshow(sharpened, cmap=plt.cm.gray)
plt.title('s')
plt.axis('off')
plt.subplot(154)
plt.imshow(canny(blurred_f,1))
plt.title('c')
plt.axis('off')
plt.subplot(155)
plt.imshow(canny(f,1))
plt.title('f_c')
plt.axis('off')


plt.tight_layout()
plt.show()
